# %%
import pickle
import matplotlib.pyplot as plt

# %%
[positions,y_values,yhat_minus_Q, yhat_plus_Q, resampled]= pickle.load(open('C:/Users/Billy/Documents/PRISMO/Executioner/gui/data.pickle','rb'))

# %%
plt.plot(resampled.index, y_values)
plt.plot(resampled.index, yhat_plus_Q)
plt.plot(resampled.index, yhat_minus_Q)
plt.xticks(resampled.index, rotation='vertical')
plt.subplots_adjust(bottom=0.15)

# %%
from datetime import datetime

# %%
datetime.strftime(resampled.index[-1],'%d-%m-%Y')
# Out:
# '20-11-2019'

# %%
str(positions[0]).replace(',','\n')
# Out:
# "Position(account='DU1651206'\n contract=Stock(conId=4081863\n symbol='TLS'\n exchange='ASX'\n currency='AUD'\n localSymbol='TLS'\n tradingClass='TLS')\n position=0.0\n avgCost=0.0)"

# %%
flatten(['a','b'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e0e7e87246ef> in <module>
# ----> 1 flatten('a','b')
#
# NameError: name 'flatten' is not defined

# %%
datetime.now().strftime('%d-%m-%Y %H-%M-%S')
# Out:
# '20-11-2019 13-54-40'

# %%
os.exists('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c4ffe59d399e> in <module>
# ----> 1 os.exists('a')
#
# AttributeError: module 'os' has no attribute 'exists'

# %%
import numpy as np

# %%
import os
